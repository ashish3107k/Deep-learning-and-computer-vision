# %%
from keras.preprocessing.image import array_to_img, img_to_array, load_img

# %%
import tensorflow as tf

# %%
model = tf.keras.models.load_model('cat_dog_model_save_15.h5')

# %%
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_9 (Conv2D)           (None, 150, 150, 16)      448
#
#  max_pooling2d_9 (MaxPooling  (None, 75, 75, 16)       0
#  2D)
#
#  dropout_3 (Dropout)         (None, 75, 75, 16)        0
#
#  conv2d_10 (Conv2D)          (None, 75, 75, 32)        4640
#
#  max_pooling2d_10 (MaxPoolin  (None, 37, 37, 32)       0
#  g2D)
#
#  dropout_4 (Dropout)         (None, 37, 37, 32)        0
#
#  conv2d_11 (Conv2D)          (None, 37, 37, 64)        18496
#
#  max_pooling2d_11 (MaxPoolin  (None, 18, 18, 64)       0
#  g2D)
#
#  dropout_5 (Dropout)         (None, 18, 18, 64)        0
#
#  flatten_3 (Flatten)         (None, 20736)             0
#
#  dense_6 (Dense)             (None, 512)               10617344
#
#  dense_7 (Dense)             (None, 1)                 513
#
# =================================================================
# Total params: 10,641,441
# Trainable params: 10,641,441
# Non-trainable params: 0
# _________________________________________________________________

# %%
data_1 = load_img('dog.jpg',target_size=(150,150))

# %%
data_1
# Out:
# <PIL.Image.Image image mode=RGB size=150x150 at 0x7F41B8E0FA90>

# %%
data_2 = img_to_array(data_1)

# %%
data_2
# Out:
# array([[[ 60.,  43.,  51.],
#         [ 61.,  50.,  46.],
#         [ 65.,  61.,  36.],
#         ...,
#         [ 79.,  70.,  65.],
#         [ 89.,  78.,  74.],
#         [ 89.,  78.,  74.]],
#
#        [[ 63.,  46.,  54.],
#         [ 64.,  53.,  49.],
#         [ 68.,  64.,  39.],
#         ...,
#         [ 80.,  71.,  66.],
#         [ 90.,  79.,  75.],
#         [ 90.,  79.,  75.]],
#
#        [[ 71.,  54.,  60.],
#         [ 71.,  60.,  56.],
#         [ 76.,  71.,  49.],
#         ...,
#         [ 83.,  74.,  69.],
#         [ 92.,  81.,  77.],
#         [ 92.,  81.,  77.]],
#
#        ...,
#
#        [[134., 149.,  90.],
#         [136., 151.,  96.],
#         [140., 152., 102.],
#         ...,
#         [ 82., 119.,  50.],
#         [ 70., 112.,  38.],
#         [ 70., 112.,  38.]],
#
#        [[129., 151.,  86.],
#         [133., 153.,  90.],
#         [139., 158., 102.],
#         ...,
#         [ 77., 114.,  45.],
#         [ 65., 107.,  33.],
#         [ 65., 107.,  33.]],
#
#        [[122., 148.,  77.],
#         [126., 151.,  85.],
#         [135., 157.,  95.],
#         ...,
#         [ 75., 112.,  43.],
#         [ 65., 107.,  33.],
#         [ 65., 107.,  33.]]], dtype=float32)

# %%
data_2.shape
# Out:
# (150, 150, 3)

# %%
img_test = data_2.reshape(1,150,150,3)

# %%
img_test
# Out:
# array([[[[ 60.,  43.,  51.],
#          [ 61.,  50.,  46.],
#          [ 65.,  61.,  36.],
#          ...,
#          [ 79.,  70.,  65.],
#          [ 89.,  78.,  74.],
#          [ 89.,  78.,  74.]],
#
#         [[ 63.,  46.,  54.],
#          [ 64.,  53.,  49.],
#          [ 68.,  64.,  39.],
#          ...,
#          [ 80.,  71.,  66.],
#          [ 90.,  79.,  75.],
#          [ 90.,  79.,  75.]],
#
#         [[ 71.,  54.,  60.],
#          [ 71.,  60.,  56.],
#          [ 76.,  71.,  49.],
#          ...,
#          [ 83.,  74.,  69.],
#          [ 92.,  81.,  77.],
#          [ 92.,  81.,  77.]],
#
#         ...,
#
#         [[134., 149.,  90.],
#          [136., 151.,  96.],
#          [140., 152., 102.],
#          ...,
#          [ 82., 119.,  50.],
#          [ 70., 112.,  38.],
#          [ 70., 112.,  38.]],
#
#         [[129., 151.,  86.],
#          [133., 153.,  90.],
#          [139., 158., 102.],
#          ...,
#          [ 77., 114.,  45.],
#          [ 65., 107.,  33.],
#          [ 65., 107.,  33.]],
#
#         [[122., 148.,  77.],
#          [126., 151.,  85.],
#          [135., 157.,  95.],
#          ...,
#          [ 75., 112.,  43.],
#          [ 65., 107.,  33.],
#          [ 65., 107.,  33.]]]], dtype=float32)

# %%
img_test.shape
# Out:
# (1, 150, 150, 3)

# %%
pred = model.predict(img_test)

# %%
pred
# Out:
# array([[1.]], dtype=float32)
